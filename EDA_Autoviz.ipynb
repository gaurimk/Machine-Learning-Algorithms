# %%
pip install AutoViz
# Out:
# Collecting AutoViz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Collecting xlrd (from AutoViz)
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: wordcloud in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (1.9.4)
# Collecting emoji (from AutoViz)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from AutoViz)
#   Downloading pyamg-5.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting scikit-learn (from AutoViz)
#   Downloading scikit_learn-1.7.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: statsmodels in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (0.14.5)
# Collecting nltk (from AutoViz)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting textblob (from AutoViz)
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting xgboost<1.7,>=0.82 (from AutoViz)
#   Downloading xgboost-1.6.2-py3-none-macosx_12_0_arm64.whl.metadata (1.8 kB)
# Collecting fsspec>=0.8.3 (from AutoViz)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (4.15.0)
# Collecting pandas-dq>=1.29 (from AutoViz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (2.1.3)
# Collecting hvplot>=0.9.2 (from AutoViz)
#   Downloading hvplot-0.12.1-py3-none-any.whl.metadata (19 kB)
# Collecting holoviews>=1.16.0 (from AutoViz)
#   Downloading holoviews-1.21.0-py3-none-any.whl.metadata (10 kB)
# Collecting panel>=1.4.0 (from AutoViz)
#   Downloading panel-1.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pandas>=2.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (2.3.2)
# Requirement already satisfied: matplotlib>3.7.4 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from AutoViz) (0.13.2)
# Requirement already satisfied: scipy in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from xgboost<1.7,>=0.82->AutoViz) (1.15.3)
# Collecting bokeh>=3.1 (from holoviews>=1.16.0->AutoViz)
#   Downloading bokeh-3.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting colorcet (from holoviews>=1.16.0->AutoViz)
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from holoviews>=1.16.0->AutoViz) (25.0)
# Collecting param<3.0,>=2.0 (from holoviews>=1.16.0->AutoViz)
#   Downloading param-2.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.16.0->AutoViz)
#   Downloading pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: Jinja2>=2.9 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from bokeh>=3.1->holoviews>=1.16.0->AutoViz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from bokeh>=3.1->holoviews>=1.16.0->AutoViz) (1.3.3)
# Collecting narwhals>=1.13 (from bokeh>=3.1->holoviews>=1.16.0->AutoViz)
#   Downloading narwhals-2.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=7.1.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from bokeh>=3.1->holoviews>=1.16.0->AutoViz) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from bokeh>=3.1->holoviews>=1.16.0->AutoViz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from bokeh>=3.1->holoviews>=1.16.0->AutoViz) (6.5.2)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1->holoviews>=1.16.0->AutoViz)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->AutoViz) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from matplotlib>3.7.4->AutoViz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from matplotlib>3.7.4->AutoViz) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from matplotlib>3.7.4->AutoViz) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from matplotlib>3.7.4->AutoViz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from matplotlib>3.7.4->AutoViz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from pandas>=2.0->AutoViz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from pandas>=2.0->AutoViz) (2025.2)
# Collecting bleach (from panel>=1.4.0->AutoViz)
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting linkify-it-py (from panel>=1.4.0->AutoViz)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel>=1.4.0->AutoViz)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel>=1.4.0->AutoViz)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdit-py-plugins (from panel>=1.4.0->AutoViz)
#   Downloading mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from panel>=1.4.0->AutoViz) (2.32.5)
# Requirement already satisfied: tqdm in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from panel>=1.4.0->AutoViz) (4.67.1)
# Requirement already satisfied: six>=1.5 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->AutoViz) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from scikit-learn->AutoViz) (1.5.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->AutoViz)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting webencodings (from bleach->panel>=1.4.0->AutoViz)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.4.0->AutoViz)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.4.0->AutoViz)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting click (from nltk->AutoViz)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting regex>=2021.8.3 (from nltk->AutoViz)
#   Downloading regex-2025.9.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from requests->panel>=1.4.0->AutoViz) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from requests->panel>=1.4.0->AutoViz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from requests->panel>=1.4.0->AutoViz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from requests->panel>=1.4.0->AutoViz) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/gaurikutakole/venv/lib/python3.11/site-packages (from statsmodels->AutoViz) (1.0.1)
# Downloading autoviz-0.1.905-py3-none-any.whl (67 kB)
# Downloading xgboost-1.6.2-py3-none-macosx_12_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 489.3 kB/s  0:00:03 eta 0:00:02
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading holoviews-1.21.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 2.0 MB/s  0:00:02m0:00:0100:01
# Downloading param-2.2.1-py3-none-any.whl (119 kB)
# Downloading bokeh-3.8.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 593.7 kB/s  0:00:11m0:00:0100:01
# Downloading hvplot-0.12.1-py3-none-any.whl (175 kB)
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading narwhals-2.4.0-py3-none-any.whl (406 kB)
# Downloading pandas_dq-1.29-py3-none-any.whl (29 kB)
# Downloading panel-1.8.0-py3-none-any.whl (30.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 1.0 MB/s  0:00:29m0:00:0100:020m
# Downloading pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Downloading scikit_learn-1.7.2-cp311-cp311-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 1.2 MB/s  0:00:07 eta 0:00:010m
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 2.5 MB/s  0:00:01m eta 0:00:01
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading regex-2025.9.1-cp311-cp311-macosx_11_0_arm64.whl (286 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Downloading pyamg-5.3.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 680.1 kB/s  0:00:02 eta 0:00:01
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: webencodings, xyzservices, xlrd, uc-micro-py, threadpoolctl, regex, param, narwhals, mdurl, markdown, fsspec, emoji, colorcet, click, bleach, xgboost, scikit-learn, pyviz-comms, pyamg, nltk, markdown-it-py, linkify-it-py, textblob, pandas-dq, mdit-py-plugins, bokeh, panel, holoviews, hvplot, AutoViz
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [AutoViz]7/30 [holoviews]rn]
# Successfully installed AutoViz-0.1.905 bleach-6.2.0 bokeh-3.8.0 click-8.2.1 colorcet-3.1.0 emoji-2.14.1 fsspec-2025.9.0 holoviews-1.21.0 hvplot-0.12.1 linkify-it-py-2.0.3 markdown-3.9 markdown-it-py-4.0.0 mdit-py-plugins-0.5.0 mdurl-0.1.2 narwhals-2.4.0 nltk-3.9.1 pandas-dq-1.29 panel-1.8.0 param-2.2.1 pyamg-5.3.0 pyviz-comms-3.0.6 regex-2025.9.1 scikit-learn-1.7.2 textblob-0.19.0 threadpoolctl-3.6.0 uc-micro-py-1.0.3 webencodings-0.5.1 xgboost-1.6.2 xlrd-2.0.2 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.to_csv('tip.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV=AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename="california_housing_train.csv"
dft=AV.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (17000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     9 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_f088d_row0_col0, #T_f088d_row0_col2, #T_f088d_row0_col5, #T_f088d_row1_col0, #T_f088d_row1_col2, #T_f088d_row1_col5, #T_f088d_row2_col0, #T_f088d_row2_col2, #T_f088d_row2_col5, #T_f088d_row3_col0, #T_f088d_row3_col2, #T_f088d_row3_col5, #T_f088d_row4_col0, #T_f088d_row4_col2, #T_f088d_row4_col5, #T_f088d_row5_col0, #T_f088d_row5_col2, #T_f088d_row5_col5, #T_f088d_row6_col0, #T_f088d_row6_col2, #T_f088d_row6_col5, #T_f088d_row7_col0, #T_f088d_row7_col2, #T_f088d_row7_col5, #T_f088d_row8_col0, #T_f088d_row8_col2, #T_f088d_row8_col5 {
#   font-family: Segoe UI;
# }
# #T_f088d_row0_col1, #T_f088d_row0_col3, #T_f088d_row0_col4, #T_f088d_row1_col1, #T_f088d_row1_col4, #T_f088d_row2_col1, #T_f088d_row2_col4, #T_f088d_row3_col1, #T_f088d_row4_col1, #T_f088d_row5_col1, #T_f088d_row6_col1, #T_f088d_row7_col1, #T_f088d_row7_col4, #T_f088d_row8_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f088d_row1_col3, #T_f088d_row2_col3, #T_f088d_row3_col3, #T_f088d_row4_col3, #T_f088d_row5_col3, #T_f088d_row6_col3, #T_f088d_row7_col3 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f088d_row3_col4 {
#   background-color: #fee8de;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f088d_row4_col4, #T_f088d_row6_col4 {
#   background-color: #fff3ed;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f088d_row5_col4 {
#   background-color: #fee9df;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f088d_row8_col3, #T_f088d_row8_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_f088d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f088d_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_f088d_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_f088d_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_f088d_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_f088d_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_f088d_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f088d_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_f088d_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_f088d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f088d_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_f088d_row0_col3" class="data row0 col3" >-124.350000</td>
#       <td id="T_f088d_row0_col4" class="data row0 col4" >-114.310000</td>
#       <td id="T_f088d_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_f088d_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_f088d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_f088d_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_f088d_row1_col3" class="data row1 col3" >32.540000</td>
#       <td id="T_f088d_row1_col4" class="data row1 col4" >41.950000</td>
#       <td id="T_f088d_row1_col5" class="data row1 col5" >Column has a high correlation with ['longitude']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_f088d_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_f088d_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f088d_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f088d_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_f088d_row2_col4" class="data row2 col4" >52.000000</td>
#       <td id="T_f088d_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_f088d_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_f088d_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f088d_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_f088d_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_f088d_row3_col4" class="data row3 col4" >37937.000000</td>
#       <td id="T_f088d_row3_col5" class="data row3 col5" >Column has 1076 outliers greater than upper bound (5685.12) or lower than lower bound(-1071.88). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row4" class="row_heading level0 row4" >total_bedrooms</th>
#       <td id="T_f088d_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_f088d_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_f088d_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_f088d_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_f088d_row4_col4" class="data row4 col4" >6445.000000</td>
#       <td id="T_f088d_row4_col5" class="data row4 col5" >Column has 1074 outliers greater than upper bound (1175.12) or lower than lower bound(-229.88). Cap them or remove them., Column has a high correlation with ['total_rooms']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row5" class="row_heading level0 row5" >population</th>
#       <td id="T_f088d_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_f088d_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_f088d_row5_col2" class="data row5 col2" >21</td>
#       <td id="T_f088d_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_f088d_row5_col4" class="data row5 col4" >35682.000000</td>
#       <td id="T_f088d_row5_col5" class="data row5 col5" >Column has 1015 outliers greater than upper bound (3117.50) or lower than lower bound(-606.50). Cap them or remove them., Column has a high correlation with ['total_rooms', 'total_bedrooms']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row6" class="row_heading level0 row6" >households</th>
#       <td id="T_f088d_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_f088d_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_f088d_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_f088d_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_f088d_row6_col4" class="data row6 col4" >6082.000000</td>
#       <td id="T_f088d_row6_col5" class="data row6 col5" >Column has 1032 outliers greater than upper bound (1090.12) or lower than lower bound(-202.88). Cap them or remove them., Column has a high correlation with ['total_rooms', 'total_bedrooms', 'population']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row7" class="row_heading level0 row7" >median_income</th>
#       <td id="T_f088d_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_f088d_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_f088d_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_f088d_row7_col3" class="data row7 col3" >0.499900</td>
#       <td id="T_f088d_row7_col4" class="data row7 col4" >15.000100</td>
#       <td id="T_f088d_row7_col5" class="data row7 col5" >Column has 563 outliers greater than upper bound (8.07) or lower than lower bound(-0.73). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f088d_level0_row8" class="row_heading level0 row8" >median_house_value</th>
#       <td id="T_f088d_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_f088d_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_f088d_row8_col2" class="data row8 col2" >21</td>
#       <td id="T_f088d_row8_col3" class="data row8 col3" >14999.000000</td>
#       <td id="T_f088d_row8_col4" class="data row8 col4" >500001.000000</td>
#       <td id="T_f088d_row8_col5" class="data row8 col5" >Column has 895 outliers greater than upper bound (483400.00) or lower than lower bound(-99000.00). Cap them or remove them.</td>
#     <
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz = 2 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
