# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target']=y

# %%
df.shape
# Out:
# (100, 6)

# %%
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0  0.527271 -1.879345  0.597206 -0.636242 -0.188971       1
# 1  0.677392 -2.835063 -0.017907 -1.002983 -1.944124       1
# 2  1.363115 -2.851096 -2.198291 -1.027712 -0.220993       0
# 3  2.912361  3.759467  1.933050 -0.944787  1.447717       0
# 4  1.808584  0.363776 -1.988756 -2.374451 -0.071034       1

# %%
df.describe()
# Out:
#              col1        col2        col3        col4        col5      target
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.768858   -1.358275   -0.804457   -0.751802    0.039042    0.510000
# std      1.168042    1.745150    1.439693    1.010524    1.505460    0.502418
# min     -1.588800   -4.636824   -4.149032   -3.531415   -3.657397    0.000000
# 25%      0.147728   -2.736139   -1.888529   -1.358259   -1.217830    0.000000
# 50%      0.636086   -1.279555   -0.756132   -0.783418    0.190360    1.000000
# 75%      1.531437   -0.208053    0.275561   -0.201777    1.173830    1.000000
# max      4.178577    3.759467    2.942866    2.937075    3.014560    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    100 non-null    float64
#  1   col2    100 non-null    float64
#  2   col3    100 non-null    float64
#  3   col4    100 non-null    float64
#  4   col5    100 non-null    float64
#  5   target  100 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
df.isnull().sum()
# Out:
# col1      0
# col2      0
# col3      0
# col4      0
# col5      0
# target    0
# dtype: int64

# %%
bag=BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf=RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()
